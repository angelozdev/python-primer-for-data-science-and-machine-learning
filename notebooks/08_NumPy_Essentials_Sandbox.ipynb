# %%
import numpy as np

# %%
a = np.array([1.5, 2, 3, 4, 5], dtype=np.float32)
a.shape, a.ndim, a.dtype, a.itemsize, a.size, a.nbytes

# %%
a = np.array([1.5, 2, 3, 4, 5], dtype=np.int32)

np.zeros((3, 4)), np.ones(3, dtype=np.int16), np.full((2, 2), 7)

# %%
np.arange(6), np.linspace(0, 1, 5)

# %%
rng = np.random.default_rng(42)
rng.normal(loc=0.0, scale=1.0, size=(10, 14))

# %%
a = np.arange(10)
b = a.reshape((2, 5))
a[0] = 99

a, b

# %%
x = np.linspace(0, 2 * np.pi, 5)
y = np.sin(x)

x, y

# %%
M = np.array([[1, 2, 3], [4, 5, 6], [7, 8, 10]])
I = np.eye(3)
M_inv = np.linalg.inv(M)
diag = np.diag([1, 2, 3])

M, I, M_inv, M @ M_inv, np.linalg.det(M), np.trace(M), diag

# %%
X = np.c_[np.arange(5), np.ones(5)]

X
